# %%
import math
x=1.5
y=math.cos(math.sin(x)-1.32)-x+0.85
e=10**(-5)
while abs(y)>e:
  x=math.cos(math.sin(x)-1.32)+0.85
  y=math.cos(math.sin(x)-1.32)-x+0.85
  print('x=',x, 'y=', y)
print('Done')
# Out:
# x= 1.798444447190017 y= -0.007639894608832409
# x= 1.7908045525811844 y= 0.0005734297912983743
# x= 1.7913779823724827 y= -4.227929251920948e-05
# x= 1.7913357030799635 y= 3.1214776026189384e-06
# Done
