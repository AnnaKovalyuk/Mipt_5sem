# %%
import math
q=0.97
e=1e-4
x0=0.5
x=10**(x0/4-1/2)
N=0
while abs(q/(1-q)*(x-x0))>e:
  N=N+1
  x0=x
  x=10**(x0/4-1/2)
  print (q/(1-q)*(x-x0))
  if N>100:
    break
print(N)
# Out:
# -0.6009469852042019
# -0.13870585914226707
# -0.031804751670818324
# -0.007281651943631075
# -0.0016665437173458313
# -0.0003813896572157172
# -8.727968994198802e-05
# 7

# %%
10^()
# Out:
# -10
