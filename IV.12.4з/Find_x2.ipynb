# %%
import math
x=4.7
N=5
for i in range(N):
  x=4*math.log10(x)+2
  print (x)
y=2*math.log10(x)-x/2+1
print('delta=', y)
# Out:
# 4.68839143174287
# 4.684095454317697
# 4.682502946848997
# 4.681912237451122
# 4.681693074308783
# delta= -4.0660126181313316e-05
