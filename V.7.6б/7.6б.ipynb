# %%
import numpy as np
from numpy import linalg as la
xy = [5,5]
def f(x, y):
    return x ** 3+ 8*y ** 3 -6*x*y+1
gradf = [3*xy[0]**2-6*xy[1],24*xy[1]**2-6*xy[0]]
e=10**(-10)
G=[[6*xy[0], -6], [-6, 48*xy[1]]]
while (gradf[0]**2+gradf[1]**2)**(0.5) > e:
  xy=xy-la.inv(G).dot(gradf)
  gradf = [3*xy[0]**2-6*xy[1],24*xy[1]**2-6*xy[0]]
  G=[[6*xy[0], -6], [-6, 48*xy[1]]]
print(xy)
# Out:
# [1.  0.5]
